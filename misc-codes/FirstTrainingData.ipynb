# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('redfin_usa_properties_dataset_sample.csv')

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.redfin.com/SC/EASTOVER/HICKORY-HIL...
# 1  https://www.redfin.com/NY/Flushing/147-35-38th...
# 2  https://www.redfin.com/TX/Unknown/1024-Indigo-...
# 3  https://www.redfin.com/OR/Redmond/3439-NW-9th-...
# 4  https://www.redfin.com/IL/Chicago/1545-N-Larra...
#
#                          name     price formatted_price currency  \
# 0             Hickory Hill Rd   40000.0         $40,000      USD
# 1    147-35 38th Ave Unit B37  415000.0        $415,000      USD
# 2          1024 Indigo Sky St  240950.0        $240,950      USD
# 3              3439 NW 9th St  466995.0        $466,995      USD
# 4  1545 N Larrabee St Unit 2N  489900.0        $489,900      USD
#
#                       address  locality region  postal_code country  ...  \
# 0             Hickory Hill Rd  Eastover     SC        29044      US  ...
# 1    147-35 38th Ave Unit B37  Flushing     NY        11354      US  ...
# ...

# %%
# df =df.drop(columns = 'url')
df.drop(columns = 'url', inplace =True)
df.head()
# Out:
#                          name     price formatted_price currency  \
# 0             Hickory Hill Rd   40000.0         $40,000      USD
# 1    147-35 38th Ave Unit B37  415000.0        $415,000      USD
# 2          1024 Indigo Sky St  240950.0        $240,950      USD
# 3              3439 NW 9th St  466995.0        $466,995      USD
# 4  1545 N Larrabee St Unit 2N  489900.0        $489,900      USD
#
#                       address  locality region  postal_code country  \
# 0             Hickory Hill Rd  Eastover     SC        29044      US
# 1    147-35 38th Ave Unit B37  Flushing     NY        11354      US
# 2          1024 Indigo Sky St   El Paso     TX        79928      US
# 3              3439 NW 9th St   Redmond     OR        97756      US
# 4  1545 N Larrabee St Unit 2N   Chicago     IL        60610      US
#
#     latitude   longitude                                        description  \
# 0  33.867386  -80.681014  This 4.13 ac of wooded land is ready for you b...
# ...

# %%
df= df.drop(columns =['latitude','longitude','images'])
df.head(10)
# Out:
#                          name       price formatted_price currency  \
# 0             Hickory Hill Rd     40000.0         $40,000      USD
# 1    147-35 38th Ave Unit B37    415000.0        $415,000      USD
# 2          1024 Indigo Sky St    240950.0        $240,950      USD
# 3              3439 NW 9th St    466995.0        $466,995      USD
# 4  1545 N Larrabee St Unit 2N    489900.0        $489,900      USD
# 5          3760 Bear Tooth Ln   1175000.0      $1,175,000      USD
# 6                 569 77th St   1299000.0      $1,299,000      USD
# 7             734 Collins Run    484900.0        $484,900      USD
# 8      1064 Taylors Island Rd  10400000.0     $10,400,000      USD
# 9                431 North St    239900.0        $239,900      USD
#
#                       address      locality region  postal_code country  \
# 0             Hickory Hill Rd      Eastover     SC        29044      US
# 1    147-35 38th Ave Unit B37      Flushing     NY        11354      US
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              39 non-null     object
#  1   price             38 non-null     float64
#  2   formatted_price   37 non-null     object
#  3   currency          39 non-null     object
#  4   address           39 non-null     object
#  5   locality          39 non-null     object
#  6   region            39 non-null     object
#  7   postal_code       39 non-null     int64
#  8   country           39 non-null     object
#  9   description       38 non-null     object
#  10  baths             39 non-null     object
#  11  beds              30 non-null     float64
#  12  sqft              39 non-null     object
#  13  property_details  39 non-null     object
#  14  listed_by         37 non-null     object
#  15  uniq_id           39 non-null     object
# ...

# %%
df['baths'].value_counts()
# Out:
# baths
# -      11
# 2      10
# 1       4
# 2.5     4
# 3       3
# 1.5     3
# 5       2
# 6       1
# 4       1
# Name: count, dtype: int64

# %%
df['baths']=df['baths'].str.replace('-','NaN')

# %%
df['baths']=df['baths'].astype(float)

# %%
df['baths'].value_counts()
# Out:
# baths
# 2.0    10
# 1.0     4
# 2.5     4
# 3.0     3
# 1.5     3
# 5.0     2
# 6.0     1
# 4.0     1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              39 non-null     object
#  1   price             38 non-null     float64
#  2   formatted_price   37 non-null     object
#  3   currency          39 non-null     object
#  4   address           39 non-null     object
#  5   locality          39 non-null     object
#  6   region            39 non-null     object
#  7   postal_code       39 non-null     int64
#  8   country           39 non-null     object
#  9   description       38 non-null     object
#  10  baths             28 non-null     float64
#  11  beds              30 non-null     float64
#  12  sqft              39 non-null     object
#  13  property_details  39 non-null     object
#  14  listed_by         37 non-null     object
#  15  uniq_id           39 non-null     object
# ...

# %%
df.head()
# Out:
#                          name     price formatted_price currency  \
# 0             Hickory Hill Rd   40000.0         $40,000      USD
# 1    147-35 38th Ave Unit B37  415000.0        $415,000      USD
# 2          1024 Indigo Sky St  240950.0        $240,950      USD
# 3              3439 NW 9th St  466995.0        $466,995      USD
# 4  1545 N Larrabee St Unit 2N  489900.0        $489,900      USD
#
#                       address  locality region  postal_code country  \
# 0             Hickory Hill Rd  Eastover     SC        29044      US
# 1    147-35 38th Ave Unit B37  Flushing     NY        11354      US
# 2          1024 Indigo Sky St   El Paso     TX        79928      US
# 3              3439 NW 9th St   Redmond     OR        97756      US
# 4  1545 N Larrabee St Unit 2N   Chicago     IL        60610      US
#
#                                          description  baths  beds   sqft  \
# 0  This 4.13 ac of wooded land is ready for you b...    NaN   NaN      -
# ...

# %%
df['region'].value_counts()
# Out:
# region
# AL    3
# TX    3
# OR    3
# PA    3
# NY    3
# SC    2
# AR    2
# KY    2
# WI    2
# OH    2
# CA    2
# DE    1
# MA    1
# MD    1
# GA    1
# CO    1
# TN    1
# AZ    1
# MO    1
# IL    1
# MI    1
# MN    1
# VA    1
# Name: count, dtype: int64

# %%
#Just Texas
df_tx=df.copy()
df_tx.head()
# Out:
#                          name     price formatted_price currency  \
# 0             Hickory Hill Rd   40000.0         $40,000      USD
# 1    147-35 38th Ave Unit B37  415000.0        $415,000      USD
# 2          1024 Indigo Sky St  240950.0        $240,950      USD
# 3              3439 NW 9th St  466995.0        $466,995      USD
# 4  1545 N Larrabee St Unit 2N  489900.0        $489,900      USD
#
#                       address  locality region  postal_code country  \
# 0             Hickory Hill Rd  Eastover     SC        29044      US
# 1    147-35 38th Ave Unit B37  Flushing     NY        11354      US
# 2          1024 Indigo Sky St   El Paso     TX        79928      US
# 3              3439 NW 9th St   Redmond     OR        97756      US
# 4  1545 N Larrabee St Unit 2N   Chicago     IL        60610      US
#
#                                          description  baths  beds   sqft  \
# 0  This 4.13 ac of wooded land is ready for you b...    NaN   NaN      -
# ...

# %%
#Filtering for Tx
df_tx['region']='TX'

# %%
df_tx['region'].value_counts()
# Out:
# region
# TX    39
# Name: count, dtype: int64

# %%
#only want 3/2 BED and Baths and above
exlcuderooms =[1,2]
df_tx=df_tx[~df_tx['beds'].isin([0,1,2])]
df_tx['beds'].value_counts()
# Out:
# beds
# 4.0    10
# 3.0     9
# 6.0     1
# 5.0     1
# Name: count, dtype: int64

# %%
df_tx=df_tx[~df_tx['baths'].isin([0,1])]
df_tx['baths'].value_counts()
# Out:
# baths
# 2.0    7
# 2.5    4
# 3.0    3
# 1.5    2
# 5.0    2
# 6.0    1
# 4.0    1
# Name: count, dtype: int64
