# %% [markdown]
# ## Checking to see if I can filiter through a list to check for ints and str using just python

# %%
animals = ['cat','dog','cat','mouse']

# %%
print(animals[1])
# Out:
# dog

# %%
userpick = await input('Please pick an animal:')
# Out:
# Please pick an animal: cat

# %%
print(userpick)
userpick=str(userpick)
# Out:
# cat

# %%
if userpick in animals:
    print('It\'s in the list ')
elif userpick not in animals:
    print('no bueno')

print(userpick)
# Out:
# It's in the list
# cat

# %%
type((userpick))
# Out:
# str

# %%
'cat' in animals
# Out:
# True

# %%
#Await input must be used on the this version of juypter for some reason. Normally it would just be input
use = await input("Pick a numb")
use=int(use)
# Out:
# Pick a numb 2

# %%
type(use)
# Out:
# int

# %%
numbs =[1,2,3]

if use in numbs:
    print('You got it')
else:
    print('Your cooked')
# Out:
# You got it

# %%
print(use)
# Out:
# 2

# %% [markdown]
# ## Creating a dataframe to practice filiter throuh data. Initally used python but it's much easier to use just Pandas

# %%
db= [[45,54,56,45,64,76],['TX','NC','FL','NC','CA']]
print(type(db))
# Out:
# <class 'list'>

# %%
import pandas as pd

# %%
df=pd.DataFrame(db)

# %%
print(df)
# Out:
#     0   1   2   3   4     5
# 0  45  54  56  45  64  76.0
# 1  TX  NC  FL  NC  CA   NaN

# %%
df.head()
# Out:
#     0   1
# 0  45  TX
# 1  54  NC
# 2  56  FL
# 3  45  NC
# 4  64  CA

# %%
df=df.transpose()

# %%
#Dropped Na values 
df.dropna(inplace=True)

# %%
df
# Out:
#     0   1   2   3   4
# 0  45  54  56  45  64
# 1  TX  NC  FL  NC  CA

# %%
#Checking placement of vales and type
list1=df[1]

# %%
list1
# Out:
# 0    54
# 1    NC
# Name: 1, dtype: object

# %%
type(list1)
# Out:
# pandas.core.series.Series

# %%
#Testing to enusre each item in list is being iterated through.
count=0
for word in list1:
    count+=1
    print(word, count)
# Out:
# 54 1
# NC 2

# %%
#User input must use 'await' in juypter
state= await input('Please pick a state: ')
# Out:
# Please pick a state:  NC

# %%
#Needed to convert series to a list in order for loop to pick it up
list1=list(list1)

# %%
if state in list1:
    print('Congrats you picked: '+state)
else:
    print('NO data on state')
# Out:
# Congrats you picked: TX

# %%
print(state)
print(type(state))
# Out:
# TX
# <class 'str'>

# %%
print(list1[0])
print(type(list1[0]))
# Out:
# TX
# <class 'str'>

# %%
state in list1
# Out:
# False

# %%
len(state)
# Out:
# 2

# %%
len(list1[0])
# Out:
# 2

# %%
print(list1)
# Out:
# ['TX', 'NC', 'FL', 'NC', 'CA']

# %%
#Cleanest way to filter dataframe with user input variable
df_filter=df[df[1]==state]

# %%
df_filter
# Out:
#     0   1
# 1  54  NC
# 3  45  NC
